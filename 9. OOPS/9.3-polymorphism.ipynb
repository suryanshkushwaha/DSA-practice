# %% [markdown]
# # Polymorphism
#
# - allows objects of different classes to be treated as objects of common superclass.
# - single way to perform single action in different forms
# - achieved through method overriding and interfaces

# %% [markdown]
# ### Method Overriding
#
# allows child class to provide a new implementation of an already implemented method in it's parent class

# %%
# Base Class


class Animal:
    def speak(self):
        return "sound of animal"


class Dog(Animal):
    def speak(self):
        return "woof!"


class Cat(Animal):
    def speak(self):
        return "meow!"


# function that demostrates polymorphism
def animal_speak(animal):
    print(animal.speak())


dog = Dog()
cat = Cat()
print(dog.speak())
animal_speak(dog)
# Out:
# woof!
# woof!

# %%
## polymorphism using func and methods


# Base class
class Shape:
    def area(self):
        return "the area of the figure"


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


from math import pi


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return pi * self.radius**2


## function demonstrating polymorphism


def print_area(shape):
    print(shape.area())


rectangle = Rectangle(4, 5)
circle = Circle(3)

print_area(rectangle)
print_area(circle)
# Out:
# 20
# 28.274333882308138

# %% [markdown]
# ## Abstract Base Class (ABC)
#
# used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promoting consistency across different implementations

# %%
# Polymorphism with Abstract Base Classes
from abc import ABC, abstractmethod


class Vehicle(ABC):
    @abstractmethod
    def start_engine(self) -> str:
        pass


class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"


class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"


def start_vehicle(vehicle):
    return vehicle.start_engine()


car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
# Out:
# 'Car engine started'
