# %% [markdown]
# # Magic Methods
#
# - predefined methods in python
# - can be overrideen
# - start and end with double underscore

# %%
"""
eg
__init__
__dir__
__str__
"""
# Out:
# '\neg \n__init__\n__dir__\n__str__\n'

# %%
class Person:
    pass


person = Person()

print(person)
# Out:
# <__main__.Person object at 0x1089d97f0>

# %%
print(person.__repr__())
# Out:
# <__main__.Person object at 0x1089d97f0>

# %%
# Basic magic methods
class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"

    def __repr__(self):
        return f"Person(name={self.name}, age={self.age})"


person = Person("suryansh", 23)
print(person)
print(repr(person))
# Out:
# suryansh, 23 years old
# Person(name=suryansh, age=23)
