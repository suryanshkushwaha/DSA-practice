# %%
# integers
age = 23
type(age)
# Out:
# int

# %%
# float
height = 6.1
type(height)
# Out:
# float

# %%
# string
name = "suryansh"
type(name)
# Out:
# str

# %%
# boolean
is_student = True
type(is_student)
# Out:
# bool

# %%
a = 10
b = 10

type(a == b)
# Out:
# bool
