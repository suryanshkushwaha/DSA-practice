# %%
import sys

l1 = []

print(sys.getsizeof(l1))

for i in range(17):
    l1.append(1)
    print(f"{i} --> {sys.getsizeof(l1)}")
# Out:
# 56
# 0 --> 88
# 1 --> 88
# 2 --> 88
# 3 --> 88
# 4 --> 120
# 5 --> 120
# 6 --> 120
# 7 --> 120
# 8 --> 184
# 9 --> 184
# 10 --> 184
# 11 --> 184
# 12 --> 184
# 13 --> 184
# 14 --> 184
# 15 --> 184
# 16 --> 248

# %%
l1.clear()

a = 1

l1.append(1)
print(id(1))

# a = 2


print(id(a))
print(id(l1[0]))

# python works via reference, all of them have the location
# Out:
# 4401047024
# 4401047056
# 4401047024
