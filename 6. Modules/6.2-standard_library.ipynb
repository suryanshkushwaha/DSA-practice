# %% [markdown]
# most commonly used libraries

# %%
import array

arr = array.array("i", [1, 2, 3, 4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random

print(random.randint(1, 10))
print(random.choice(["apple", "bababab"]))
# Out:
# 10
# bababab

# %%
import os

print(os.getcwd())
# Out:
# /Users/sillymac/sillysurry/1. Personal/3. Learning/DSA-practice/6. Modules

# %%
os.mkdir("test_dir")

# %%
import shutil

shutil.copyfile("source.txt", "destination.txt")
# Out:
# 'destination.txt'

# %%
import json

data = {"name": "suryansh", "age": 25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "suryansh", "age": 25}
# <class 'str'>
# {'name': 'suryansh', 'age': 25}
# <class 'dict'>

# %%
import csv

with open("example.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["name", "age"])
    writer.writerow(["suryansh", 23])

with open("example.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['suryansh', '23']

# %%
import datetime

now = datetime.datetime.now()
print(now)

yesterday = now - datetime.timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-16 22:15:10.423197
# 2026-03-15 22:15:10.423197

# %%
import time

print(time.time())
time.sleep(5)
print(time.time())
# Out:
# 1773670533.503427
# 1773670538.509042

# %%
import re

pattern = r"\d+"
text = "there are 123 apples 456"
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
